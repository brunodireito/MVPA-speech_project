# %%
import pandas as pd
import csv

# %%
# read .prt file
root_data="E:\\DATA\\DATA_Carlos_Phonos\\"

prt_file=root_data+'JoaoPereira/001/run-fonologico-data/PROJECT/ANALYSIS/Fonologico.prt'

conds=['Baseline ', 'Task ']
c_numel=[]
events_num=[]
TR=2.5
onset=[]
duration=[]
trial_type=[]

# open file.
with open(prt_file, newline = '') as f_reader:
    l=f_reader.readline()
    for idx, c in enumerate(conds):
        while not c in l:
            l = f_reader.readline()
        # read number of events.
        events_num.append(int(f_reader.readline()))
        print(c,int(events_num[idx]))
        # read events
        for e in range(int(events_num[idx])):
            temp_TR=f_reader.readline().split()
            # onset - TR to sec
            onset_sec=(int(temp_TR[0])-1)*TR       
            onset.append(onset_sec)
            duration_sec=(int(temp_TR[1])-int(temp_TR[0]))*TR
            # duration - TR to sec
            duration.append(duration_sec)
            trial_type.append(c)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-300f413aad87> in <module>
#      13
#      14 # open file.
# ---> 15 with open(prt_file, newline = '') as f_reader:
#      16     l=f_reader.readline()
#      17     for idx, c in enumerate(conds):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\DATA\\DATA_Carlos_Phonos\\JoaoPereira/001/run-fonologico-data/PROJECT/ANALYSIS/Fonologico.prt'

# %%
import pandas as pd
events = pd.DataFrame({'trial_type': trial_type,
                       'onset': onset,
                       'duration': duration})

# %%
events
# Out:
#    trial_type  onset  duration
# 0   Baseline     0.0      12.5
# 1   Baseline    45.0      12.5
# 2   Baseline    90.0      12.5
# 3   Baseline   135.0      12.5
# 4   Baseline   180.0      12.5
# 5   Baseline   225.0      12.5
# 6   Baseline   270.0      12.5
# 7   Baseline   315.0      12.5
# 8   Baseline   360.0      12.5
# 9   Baseline   405.0      12.5
# 10  Baseline   450.0      12.5
# 11  Baseline   495.0      12.5
# 12  Baseline   540.0      12.5
# 13      Task    15.0      27.5
# 14      Task    60.0      27.5
# 15      Task   105.0      27.5
# 16      Task   150.0      27.5
# 17      Task   195.0      27.5
# 18      Task   240.0      27.5
# 19      Task   285.0      27.5
# 20      Task   330.0      27.5
# 21      Task   375.0      27.5
# 22      Task   420.0      27.5
# 23      Task   465.0      27.5
# 24      Task   510.0      27.5

# %%
events=events.sort_values('onset')
events=events.reset_index(drop=True)
events
# Out:
#    trial_type  onset  duration
# 0   Baseline     0.0      12.5
# 1       Task    15.0      27.5
# 2   Baseline    45.0      12.5
# 3       Task    60.0      27.5
# 4   Baseline    90.0      12.5
# 5       Task   105.0      27.5
# 6   Baseline   135.0      12.5
# 7       Task   150.0      27.5
# 8   Baseline   180.0      12.5
# 9       Task   195.0      27.5
# 10  Baseline   225.0      12.5
# 11      Task   240.0      27.5
# 12  Baseline   270.0      12.5
# 13      Task   285.0      27.5
# 14  Baseline   315.0      12.5
# 15      Task   330.0      27.5
# 16  Baseline   360.0      12.5
# 17      Task   375.0      27.5
# 18  Baseline   405.0      12.5
# 19      Task   420.0      27.5
# 20  Baseline   450.0      12.5
# 21      Task   465.0      27.5
# 22  Baseline   495.0      12.5
# 23      Task   510.0      27.5
# 24  Baseline   540.0      12.5

# %%
tsvfile = 'events_fonologico.tsv'
events.to_csv(tsvfile, sep='\t', index=False)
print("Created the events file in %s " % tsvfile)
# Out:
# Created the events file in events.tsv

# %% [markdown]
# events

# %%
idxs=events['onset']/TR
ev_epoched=[]

for i in range(len(events)):
    idx_2=((events['duration'][i]/TR))+1
    for j in range(int(idx_2)):
        ev_epoched.append(events['trial_type'][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c24b2cf614c> in <module>
# ----> 1 idxs=events['onset']/TR
#       2 ev_epoched=[]
#       3
#       4 for i in range(len(events)):
#       5     idx_2=((events['duration'][i]/TR))+1
#
# NameError: name 'events' is not defined
